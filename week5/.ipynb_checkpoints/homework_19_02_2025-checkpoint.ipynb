# %% [markdown]
# # Homework:
#
# 1)Given the dataframe attached "df3.csv", which columns contributed to creating the column "f"?
#
# 2)Plot the function y = 1/x between -10 and 10
#
# 3)Recreate the following heatmaps:
#
# <img src="attachment:3d81cdf7-b18d-4d78-8713-ce02742c9d1c.png" alt="Drawing" style="width: 200px;"/>,
# <img src="attachment:3aa4d5c8-6c88-436c-b48b-5d3cb0c7d19d.png" alt="Drawing" style="width: 200px;"/>,
# <img src="attachment:945c6609-38e8-4f42-afbf-fb01ef4483bb.png" alt="Drawing" style="width: 200px;"/>

# %%
# !pip install pandas==1.5.3
# !pip install plotly==6.0.0
# !pip install matplotlib==3.10.0
# !pip install seaborn==0.13.2
# !pip install statsmodels
# Out:
# Collecting pandas==1.5.3
#   Using cached pandas-1.5.3.tar.gz (5.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: still running...
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.21.0 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from pandas==1.5.3) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from pandas==1.5.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from pandas==1.5.3) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.17.0)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (pyproject.toml): started
#   Building wheel for pandas (pyproject.toml): finished with status 'error'
# Failed to build pandas
#   error: subprocess-exited-with-error
#
#   Building wheel for pandas (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [2514 lines of output]
#   <string>:19: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-313\pandas
#   copying pandas\conftest.py -> build\lib.win-amd64-cpython-313\pandas
#   copying pandas\testing.py -> build\lib.win-amd64-cpython-313\pandas
#   copying pandas\_typing.py -> build\lib.win-amd64-cpython-313\pandas
#   copying pandas\_version.py -> build\lib.win-amd64-cpython-313\pandas
#   copying pandas\__init__.py -> build\lib.win-amd64-cpython-313\pandas
#   creating build\lib.win-amd64-cpython-313\pandas\api
#   copying pandas\api\__init__.py -> build\lib.win-amd64-cpython-313\pandas\api
#   creating build\lib.win-amd64-cpython-313\pandas\arrays
#   copying pandas\arrays\__init__.py -> build\lib.win-amd64-cpython-313\pandas\arrays
#   creating build\lib.win-amd64-cpython-313\pandas\compat
#   copying pandas\compat\chainmap.py -> build\lib.win-amd64-cpython-313\pandas\compat
#   copying pandas\compat\pickle_compat.py -> build\lib.win-amd64-cpython-313\pandas\compat
#   copying pandas\compat\pyarrow.py -> build\lib.win-amd64-cpython-313\pandas\compat
#   copying pandas\compat\_optional.py -> build\lib.win-amd64-cpython-313\pandas\compat
#   copying pandas\compat\__init__.py -> build\lib.win-amd64-cpython-313\pandas\compat
#   creating build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\accessor.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\algorithms.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\api.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\apply.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\arraylike.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\base.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\common.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\config_init.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\construction.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\describe.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\flags.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\frame.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\generic.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\index.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\indexing.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\missing.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\nanops.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\resample.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\roperator.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\sample.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\series.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\shared_docs.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\sorting.py -> build\lib.win-amd64-cpython-313\pandas\core
#   copying pandas\core\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core
#   creating build\lib.win-amd64-cpython-313\pandas\errors
#   copying pandas\errors\__init__.py -> build\lib.win-amd64-cpython-313\pandas\errors
#   creating build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\api.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\clipboards.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\common.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\date_converters.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\feather_format.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\gbq.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\html.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\orc.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\parquet.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\pickle.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\pytables.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\spss.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\sql.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\stata.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\xml.py -> build\lib.win-amd64-cpython-313\pandas\io
#   copying pandas\io\__init__.py -> build\lib.win-amd64-cpython-313\pandas\io
#   creating build\lib.win-amd64-cpython-313\pandas\plotting
#   copying pandas\plotting\_core.py -> build\lib.win-amd64-cpython-313\pandas\plotting
#   copying pandas\plotting\_misc.py -> build\lib.win-amd64-cpython-313\pandas\plotting
#   copying pandas\plotting\__init__.py -> build\lib.win-amd64-cpython-313\pandas\plotting
#   creating build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_aggregation.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_algos.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_common.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_downstream.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_errors.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_expressions.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_flags.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_multilevel.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_nanops.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_optional_dependency.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_register_accessor.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_sorting.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\test_take.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   copying pandas\tests\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests
#   creating build\lib.win-amd64-cpython-313\pandas\tseries
#   copying pandas\tseries\api.py -> build\lib.win-amd64-cpython-313\pandas\tseries
#   copying pandas\tseries\frequencies.py -> build\lib.win-amd64-cpython-313\pandas\tseries
#   copying pandas\tseries\holiday.py -> build\lib.win-amd64-cpython-313\pandas\tseries
#   copying pandas\tseries\offsets.py -> build\lib.win-amd64-cpython-313\pandas\tseries
#   copying pandas\tseries\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tseries
#   creating build\lib.win-amd64-cpython-313\pandas\util
#   copying pandas\util\testing.py -> build\lib.win-amd64-cpython-313\pandas\util
#   copying pandas\util\_decorators.py -> build\lib.win-amd64-cpython-313\pandas\util
#   copying pandas\util\_doctools.py -> build\lib.win-amd64-cpython-313\pandas\util
#   copying pandas\util\_exceptions.py -> build\lib.win-amd64-cpython-313\pandas\util
#   copying pandas\util\_print_versions.py -> build\lib.win-amd64-cpython-313\pandas\util
#   copying pandas\util\_tester.py -> build\lib.win-amd64-cpython-313\pandas\util
#   copying pandas\util\_test_decorators.py -> build\lib.win-amd64-cpython-313\pandas\util
#   copying pandas\util\_validators.py -> build\lib.win-amd64-cpython-313\pandas\util
#   copying pandas\util\__init__.py -> build\lib.win-amd64-cpython-313\pandas\util
#   creating build\lib.win-amd64-cpython-313\pandas\_config
#   copying pandas\_config\config.py -> build\lib.win-amd64-cpython-313\pandas\_config
#   copying pandas\_config\dates.py -> build\lib.win-amd64-cpython-313\pandas\_config
#   copying pandas\_config\display.py -> build\lib.win-amd64-cpython-313\pandas\_config
#   copying pandas\_config\localization.py -> build\lib.win-amd64-cpython-313\pandas\_config
#   copying pandas\_config\__init__.py -> build\lib.win-amd64-cpython-313\pandas\_config
#   creating build\lib.win-amd64-cpython-313\pandas\_libs
#   copying pandas\_libs\__init__.py -> build\lib.win-amd64-cpython-313\pandas\_libs
#   creating build\lib.win-amd64-cpython-313\pandas\_testing
#   copying pandas\_testing\asserters.py -> build\lib.win-amd64-cpython-313\pandas\_testing
#   copying pandas\_testing\compat.py -> build\lib.win-amd64-cpython-313\pandas\_testing
#   copying pandas\_testing\contexts.py -> build\lib.win-amd64-cpython-313\pandas\_testing
#   copying pandas\_testing\_hypothesis.py -> build\lib.win-amd64-cpython-313\pandas\_testing
#   copying pandas\_testing\_io.py -> build\lib.win-amd64-cpython-313\pandas\_testing
#   copying pandas\_testing\_random.py -> build\lib.win-amd64-cpython-313\pandas\_testing
#   copying pandas\_testing\_warnings.py -> build\lib.win-amd64-cpython-313\pandas\_testing
#   copying pandas\_testing\__init__.py -> build\lib.win-amd64-cpython-313\pandas\_testing
#   creating build\lib.win-amd64-cpython-313\pandas\api\extensions
#   copying pandas\api\extensions\__init__.py -> build\lib.win-amd64-cpython-313\pandas\api\extensions
#   creating build\lib.win-amd64-cpython-313\pandas\api\indexers
#   copying pandas\api\indexers\__init__.py -> build\lib.win-amd64-cpython-313\pandas\api\indexers
#   creating build\lib.win-amd64-cpython-313\pandas\api\interchange
#   copying pandas\api\interchange\__init__.py -> build\lib.win-amd64-cpython-313\pandas\api\interchange
#   creating build\lib.win-amd64-cpython-313\pandas\api\types
#   copying pandas\api\types\__init__.py -> build\lib.win-amd64-cpython-313\pandas\api\types
#   creating build\lib.win-amd64-cpython-313\pandas\compat\numpy
#   copying pandas\compat\numpy\function.py -> build\lib.win-amd64-cpython-313\pandas\compat\numpy
#   copying pandas\compat\numpy\__init__.py -> build\lib.win-amd64-cpython-313\pandas\compat\numpy
#   creating build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\base.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\boolean.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\categorical.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\datetimelike.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\datetimes.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\floating.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\integer.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\interval.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\masked.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\numeric.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\numpy_.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\period.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\string_.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\string_arrow.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\timedeltas.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\_mixins.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\_ranges.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   copying pandas\core\arrays\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays
#   creating build\lib.win-amd64-cpython-313\pandas\core\array_algos
#   copying pandas\core\array_algos\masked_reductions.py -> build\lib.win-amd64-cpython-313\pandas\core\array_algos
#   copying pandas\core\array_algos\putmask.py -> build\lib.win-amd64-cpython-313\pandas\core\array_algos
#   copying pandas\core\array_algos\quantile.py -> build\lib.win-amd64-cpython-313\pandas\core\array_algos
#   copying pandas\core\array_algos\replace.py -> build\lib.win-amd64-cpython-313\pandas\core\array_algos
#   copying pandas\core\array_algos\take.py -> build\lib.win-amd64-cpython-313\pandas\core\array_algos
#   copying pandas\core\array_algos\transforms.py -> build\lib.win-amd64-cpython-313\pandas\core\array_algos
#   copying pandas\core\array_algos\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\array_algos
#   creating build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\align.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\api.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\check.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\common.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\engines.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\eval.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\expr.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\expressions.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\ops.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\parsing.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\pytables.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\scope.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   copying pandas\core\computation\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\computation
#   creating build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   copying pandas\core\dtypes\api.py -> build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   copying pandas\core\dtypes\astype.py -> build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   copying pandas\core\dtypes\base.py -> build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   copying pandas\core\dtypes\cast.py -> build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   copying pandas\core\dtypes\common.py -> build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   copying pandas\core\dtypes\concat.py -> build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   copying pandas\core\dtypes\dtypes.py -> build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   copying pandas\core\dtypes\generic.py -> build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   copying pandas\core\dtypes\inference.py -> build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   copying pandas\core\dtypes\missing.py -> build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   copying pandas\core\dtypes\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\dtypes
#   creating build\lib.win-amd64-cpython-313\pandas\core\groupby
#   copying pandas\core\groupby\base.py -> build\lib.win-amd64-cpython-313\pandas\core\groupby
#   copying pandas\core\groupby\categorical.py -> build\lib.win-amd64-cpython-313\pandas\core\groupby
#   copying pandas\core\groupby\generic.py -> build\lib.win-amd64-cpython-313\pandas\core\groupby
#   copying pandas\core\groupby\groupby.py -> build\lib.win-amd64-cpython-313\pandas\core\groupby
#   copying pandas\core\groupby\grouper.py -> build\lib.win-amd64-cpython-313\pandas\core\groupby
#   copying pandas\core\groupby\indexing.py -> build\lib.win-amd64-cpython-313\pandas\core\groupby
#   copying pandas\core\groupby\numba_.py -> build\lib.win-amd64-cpython-313\pandas\core\groupby
#   copying pandas\core\groupby\ops.py -> build\lib.win-amd64-cpython-313\pandas\core\groupby
#   copying pandas\core\groupby\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\groupby
#   creating build\lib.win-amd64-cpython-313\pandas\core\indexers
#   copying pandas\core\indexers\objects.py -> build\lib.win-amd64-cpython-313\pandas\core\indexers
#   copying pandas\core\indexers\utils.py -> build\lib.win-amd64-cpython-313\pandas\core\indexers
#   copying pandas\core\indexers\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\indexers
#   creating build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\accessors.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\api.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\base.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\category.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\datetimelike.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\datetimes.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\extension.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\frozen.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\interval.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\multi.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\numeric.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\period.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\range.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\timedeltas.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   copying pandas\core\indexes\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\indexes
#   creating build\lib.win-amd64-cpython-313\pandas\core\interchange
#   copying pandas\core\interchange\buffer.py -> build\lib.win-amd64-cpython-313\pandas\core\interchange
#   copying pandas\core\interchange\column.py -> build\lib.win-amd64-cpython-313\pandas\core\interchange
#   copying pandas\core\interchange\dataframe.py -> build\lib.win-amd64-cpython-313\pandas\core\interchange
#   copying pandas\core\interchange\dataframe_protocol.py -> build\lib.win-amd64-cpython-313\pandas\core\interchange
#   copying pandas\core\interchange\from_dataframe.py -> build\lib.win-amd64-cpython-313\pandas\core\interchange
#   copying pandas\core\interchange\utils.py -> build\lib.win-amd64-cpython-313\pandas\core\interchange
#   copying pandas\core\interchange\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\interchange
#   creating build\lib.win-amd64-cpython-313\pandas\core\internals
#   copying pandas\core\internals\api.py -> build\lib.win-amd64-cpython-313\pandas\core\internals
#   copying pandas\core\internals\array_manager.py -> build\lib.win-amd64-cpython-313\pandas\core\internals
#   copying pandas\core\internals\base.py -> build\lib.win-amd64-cpython-313\pandas\core\internals
#   copying pandas\core\internals\blocks.py -> build\lib.win-amd64-cpython-313\pandas\core\internals
#   copying pandas\core\internals\concat.py -> build\lib.win-amd64-cpython-313\pandas\core\internals
#   copying pandas\core\internals\construction.py -> build\lib.win-amd64-cpython-313\pandas\core\internals
#   copying pandas\core\internals\managers.py -> build\lib.win-amd64-cpython-313\pandas\core\internals
#   copying pandas\core\internals\ops.py -> build\lib.win-amd64-cpython-313\pandas\core\internals
#   copying pandas\core\internals\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\internals
#   creating build\lib.win-amd64-cpython-313\pandas\core\ops
#   copying pandas\core\ops\array_ops.py -> build\lib.win-amd64-cpython-313\pandas\core\ops
#   copying pandas\core\ops\common.py -> build\lib.win-amd64-cpython-313\pandas\core\ops
#   copying pandas\core\ops\dispatch.py -> build\lib.win-amd64-cpython-313\pandas\core\ops
#   copying pandas\core\ops\docstrings.py -> build\lib.win-amd64-cpython-313\pandas\core\ops
#   copying pandas\core\ops\invalid.py -> build\lib.win-amd64-cpython-313\pandas\core\ops
#   copying pandas\core\ops\mask_ops.py -> build\lib.win-amd64-cpython-313\pandas\core\ops
#   copying pandas\core\ops\methods.py -> build\lib.win-amd64-cpython-313\pandas\core\ops
#   copying pandas\core\ops\missing.py -> build\lib.win-amd64-cpython-313\pandas\core\ops
#   copying pandas\core\ops\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\ops
#   creating build\lib.win-amd64-cpython-313\pandas\core\reshape
#   copying pandas\core\reshape\api.py -> build\lib.win-amd64-cpython-313\pandas\core\reshape
#   copying pandas\core\reshape\concat.py -> build\lib.win-amd64-cpython-313\pandas\core\reshape
#   copying pandas\core\reshape\encoding.py -> build\lib.win-amd64-cpython-313\pandas\core\reshape
#   copying pandas\core\reshape\melt.py -> build\lib.win-amd64-cpython-313\pandas\core\reshape
#   copying pandas\core\reshape\merge.py -> build\lib.win-amd64-cpython-313\pandas\core\reshape
#   copying pandas\core\reshape\pivot.py -> build\lib.win-amd64-cpython-313\pandas\core\reshape
#   copying pandas\core\reshape\reshape.py -> build\lib.win-amd64-cpython-313\pandas\core\reshape
#   copying pandas\core\reshape\tile.py -> build\lib.win-amd64-cpython-313\pandas\core\reshape
#   copying pandas\core\reshape\util.py -> build\lib.win-amd64-cpython-313\pandas\core\reshape
#   copying pandas\core\reshape\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\reshape
#   creating build\lib.win-amd64-cpython-313\pandas\core\sparse
#   copying pandas\core\sparse\api.py -> build\lib.win-amd64-cpython-313\pandas\core\sparse
#   copying pandas\core\sparse\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\sparse
#   creating build\lib.win-amd64-cpython-313\pandas\core\strings
#   copying pandas\core\strings\accessor.py -> build\lib.win-amd64-cpython-313\pandas\core\strings
#   copying pandas\core\strings\base.py -> build\lib.win-amd64-cpython-313\pandas\core\strings
#   copying pandas\core\strings\object_array.py -> build\lib.win-amd64-cpython-313\pandas\core\strings
#   copying pandas\core\strings\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\strings
#   creating build\lib.win-amd64-cpython-313\pandas\core\tools
#   copying pandas\core\tools\datetimes.py -> build\lib.win-amd64-cpython-313\pandas\core\tools
#   copying pandas\core\tools\numeric.py -> build\lib.win-amd64-cpython-313\pandas\core\tools
#   copying pandas\core\tools\timedeltas.py -> build\lib.win-amd64-cpython-313\pandas\core\tools
#   copying pandas\core\tools\times.py -> build\lib.win-amd64-cpython-313\pandas\core\tools
#   copying pandas\core\tools\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\tools
#   creating build\lib.win-amd64-cpython-313\pandas\core\util
#   copying pandas\core\util\hashing.py -> build\lib.win-amd64-cpython-313\pandas\core\util
#   copying pandas\core\util\numba_.py -> build\lib.win-amd64-cpython-313\pandas\core\util
#   copying pandas\core\util\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\util
#   creating build\lib.win-amd64-cpython-313\pandas\core\window
#   copying pandas\core\window\common.py -> build\lib.win-amd64-cpython-313\pandas\core\window
#   copying pandas\core\window\doc.py -> build\lib.win-amd64-cpython-313\pandas\core\window
#   copying pandas\core\window\ewm.py -> build\lib.win-amd64-cpython-313\pandas\core\window
#   copying pandas\core\window\expanding.py -> build\lib.win-amd64-cpython-313\pandas\core\window
#   copying pandas\core\window\numba_.py -> build\lib.win-amd64-cpython-313\pandas\core\window
#   copying pandas\core\window\online.py -> build\lib.win-amd64-cpython-313\pandas\core\window
#   copying pandas\core\window\rolling.py -> build\lib.win-amd64-cpython-313\pandas\core\window
#   copying pandas\core\window\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\window
#   creating build\lib.win-amd64-cpython-313\pandas\core\_numba
#   copying pandas\core\_numba\executor.py -> build\lib.win-amd64-cpython-313\pandas\core\_numba
#   copying pandas\core\_numba\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\_numba
#   creating build\lib.win-amd64-cpython-313\pandas\core\arrays\arrow
#   copying pandas\core\arrays\arrow\array.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays\arrow
#   copying pandas\core\arrays\arrow\dtype.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays\arrow
#   copying pandas\core\arrays\arrow\extension_types.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays\arrow
#   copying pandas\core\arrays\arrow\_arrow_utils.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays\arrow
#   copying pandas\core\arrays\arrow\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays\arrow
#   creating build\lib.win-amd64-cpython-313\pandas\core\arrays\sparse
#   copying pandas\core\arrays\sparse\accessor.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays\sparse
#   copying pandas\core\arrays\sparse\array.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays\sparse
#   copying pandas\core\arrays\sparse\dtype.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays\sparse
#   copying pandas\core\arrays\sparse\scipy_sparse.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays\sparse
#   copying pandas\core\arrays\sparse\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\arrays\sparse
#   creating build\lib.win-amd64-cpython-313\pandas\core\_numba\kernels
#   copying pandas\core\_numba\kernels\mean_.py -> build\lib.win-amd64-cpython-313\pandas\core\_numba\kernels
#   copying pandas\core\_numba\kernels\min_max_.py -> build\lib.win-amd64-cpython-313\pandas\core\_numba\kernels
#   copying pandas\core\_numba\kernels\shared.py -> build\lib.win-amd64-cpython-313\pandas\core\_numba\kernels
#   copying pandas\core\_numba\kernels\sum_.py -> build\lib.win-amd64-cpython-313\pandas\core\_numba\kernels
#   copying pandas\core\_numba\kernels\var_.py -> build\lib.win-amd64-cpython-313\pandas\core\_numba\kernels
#   copying pandas\core\_numba\kernels\__init__.py -> build\lib.win-amd64-cpython-313\pandas\core\_numba\kernels
#   creating build\lib.win-amd64-cpython-313\pandas\io\clipboard
#   copying pandas\io\clipboard\__init__.py -> build\lib.win-amd64-cpython-313\pandas\io\clipboard
#   creating build\lib.win-amd64-cpython-313\pandas\io\excel
#   copying pandas\io\excel\_base.py -> build\lib.win-amd64-cpython-313\pandas\io\excel
#   copying pandas\io\excel\_odfreader.py -> build\lib.win-amd64-cpython-313\pandas\io\excel
#   copying pandas\io\excel\_odswriter.py -> build\lib.win-amd64-cpython-313\pandas\io\excel
#   copying pandas\io\excel\_openpyxl.py -> build\lib.win-amd64-cpython-313\pandas\io\excel
#   copying pandas\io\excel\_pyxlsb.py -> build\lib.win-amd64-cpython-313\pandas\io\excel
#   copying pandas\io\excel\_util.py -> build\lib.win-amd64-cpython-313\pandas\io\excel
#   copying pandas\io\excel\_xlrd.py -> build\lib.win-amd64-cpython-313\pandas\io\excel
#   copying pandas\io\excel\_xlsxwriter.py -> build\lib.win-amd64-cpython-313\pandas\io\excel
#   copying pandas\io\excel\_xlwt.py -> build\lib.win-amd64-cpython-313\pandas\io\excel
#   copying pandas\io\excel\__init__.py -> build\lib.win-amd64-cpython-313\pandas\io\excel
#   creating build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\console.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\css.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\csvs.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\excel.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\format.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\html.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\info.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\latex.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\printing.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\string.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\style.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\style_render.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\xml.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\_color_data.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   copying pandas\io\formats\__init__.py -> build\lib.win-amd64-cpython-313\pandas\io\formats
#   creating build\lib.win-amd64-cpython-313\pandas\io\json
#   copying pandas\io\json\_json.py -> build\lib.win-amd64-cpython-313\pandas\io\json
#   copying pandas\io\json\_normalize.py -> build\lib.win-amd64-cpython-313\pandas\io\json
#   copying pandas\io\json\_table_schema.py -> build\lib.win-amd64-cpython-313\pandas\io\json
#   copying pandas\io\json\__init__.py -> build\lib.win-amd64-cpython-313\pandas\io\json
#   creating build\lib.win-amd64-cpython-313\pandas\io\parsers
#   copying pandas\io\parsers\arrow_parser_wrapper.py -> build\lib.win-amd64-cpython-313\pandas\io\parsers
#   copying pandas\io\parsers\base_parser.py -> build\lib.win-amd64-cpython-313\pandas\io\parsers
#   copying pandas\io\parsers\c_parser_wrapper.py -> build\lib.win-amd64-cpython-313\pandas\io\parsers
#   copying pandas\io\parsers\python_parser.py -> build\lib.win-amd64-cpython-313\pandas\io\parsers
#   copying pandas\io\parsers\readers.py -> build\lib.win-amd64-cpython-313\pandas\io\parsers
#   copying pandas\io\parsers\__init__.py -> build\lib.win-amd64-cpython-313\pandas\io\parsers
#   creating build\lib.win-amd64-cpython-313\pandas\io\sas
#   copying pandas\io\sas\sas7bdat.py -> build\lib.win-amd64-cpython-313\pandas\io\sas
#   copying pandas\io\sas\sasreader.py -> build\lib.win-amd64-cpython-313\pandas\io\sas
#   copying pandas\io\sas\sas_constants.py -> build\lib.win-amd64-cpython-313\pandas\io\sas
#   copying pandas\io\sas\sas_xport.py -> build\lib.win-amd64-cpython-313\pandas\io\sas
#   copying pandas\io\sas\__init__.py -> build\lib.win-amd64-cpython-313\pandas\io\sas
#   creating build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\boxplot.py -> build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\compat.py -> build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\converter.py -> build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\core.py -> build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\groupby.py -> build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\hist.py -> build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\misc.py -> build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\style.py -> build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\timeseries.py -> build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\tools.py -> build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   copying pandas\plotting\_matplotlib\__init__.py -> build\lib.win-amd64-cpython-313\pandas\plotting\_matplotlib
#   creating build\lib.win-amd64-cpython-313\pandas\tests\api
#   copying pandas\tests\api\test_api.py -> build\lib.win-amd64-cpython-313\pandas\tests\api
#   copying pandas\tests\api\test_types.py -> build\lib.win-amd64-cpython-313\pandas\tests\api
#   copying pandas\tests\api\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\api
#   creating build\lib.win-amd64-cpython-313\pandas\tests\apply
#   copying pandas\tests\apply\common.py -> build\lib.win-amd64-cpython-313\pandas\tests\apply
#   copying pandas\tests\apply\conftest.py -> build\lib.win-amd64-cpython-313\pandas\tests\apply
#   copying pandas\tests\apply\test_frame_apply.py -> build\lib.win-amd64-cpython-313\pandas\tests\apply
#   copying pandas\tests\apply\test_frame_apply_relabeling.py -> build\lib.win-amd64-cpython-313\pandas\tests\apply
#   copying pandas\tests\apply\test_frame_transform.py -> build\lib.win-amd64-cpython-313\pandas\tests\apply
#   copying pandas\tests\apply\test_invalid_arg.py -> build\lib.win-amd64-cpython-313\pandas\tests\apply
#   copying pandas\tests\apply\test_series_apply.py -> build\lib.win-amd64-cpython-313\pandas\tests\apply
#   copying pandas\tests\apply\test_series_apply_relabeling.py -> build\lib.win-amd64-cpython-313\pandas\tests\apply
#   copying pandas\tests\apply\test_series_transform.py -> build\lib.win-amd64-cpython-313\pandas\tests\apply
#   copying pandas\tests\apply\test_str.py -> build\lib.win-amd64-cpython-313\pandas\tests\apply
#   copying pandas\tests\apply\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\apply
#   creating build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\common.py -> build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\conftest.py -> build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_array_ops.py -> build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_categorical.py -> build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_datetime64.py -> build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_interval.py -> build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_numeric.py -> build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_object.py -> build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_period.py -> build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\test_timedelta64.py -> build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   copying pandas\tests\arithmetic\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\arithmetic
#   creating build\lib.win-amd64-cpython-313\pandas\tests\arrays
#   copying pandas\tests\arrays\masked_shared.py -> build\lib.win-amd64-cpython-313\pandas\tests\arrays
#   copying pandas\tests\arrays\test_array.py -> build\lib.win-amd64-cpython-313\pandas\tests\arrays
#   copying pandas\tests\arrays\test_datetimelike.py -> build\lib.win-amd64-cpython-313\pandas\tests\arrays
#   copying pandas\tests\arrays\test_datetimes.py -> build\lib.win-amd64-cpython-313\pandas\tests\arrays
#   copying pandas\tests\arrays\test_ndarray_backed.py -> build\lib.win-amd64-cpython-313\pandas\tests\arrays
#   copying pandas\tests\arrays\test_period.py -> build\lib.win-amd64-cpython-313\pandas\tests\arrays
#   copying pandas\tests\arrays\test_timedeltas.py -> build\lib.win-amd64-cpython-313\pandas\tests\arrays
#   copying pandas\tests\arrays\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\arrays
#   creating build\lib.win-amd64-cpython-313\pandas\tests\base
#   copying pandas\tests\base\common.py -> build\lib.win-amd64-cpython-313\pandas\tests\base
#   copying pandas\tests\base\test_constructors.py -> build\lib.win-amd64-cpython-313\pandas\tests\base
#   copying pandas\tests\base\test_conversion.py -> build\lib.win-amd64-cpython-313\pandas\tests\base
#   copying pandas\tests\base\test_fillna.py -> build\lib.win-amd64-cpython-313\pandas\tests\base
#   copying pandas\tests\base\test_misc.py -> build\lib.win-amd64-cpython-313\pandas\tests\base
#   copying pandas\tests\base\test_transpose.py -> build\lib.win-amd64-cpython-313\pandas\tests\base
#   copying pandas\tests\base\test_unique.py -> build\lib.win-amd64-cpython-313\pandas\tests\base
#   copying pandas\tests\base\test_value_counts.py -> build\lib.win-amd64-cpython-313\pandas\tests\base
#   copying pandas\tests\base\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\base
#   creating build\lib.win-amd64-cpython-313\pandas\tests\computation
#   copying pandas\tests\computation\test_compat.py -> build\lib.win-amd64-cpython-313\pandas\tests\computation
#   copying pandas\tests\computation\test_eval.py -> build\lib.win-amd64-cpython-313\pandas\tests\computation
#   copying pandas\tests\computation\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\computation
#   creating build\lib.win-amd64-cpython-313\pandas\tests\config
#   copying pandas\tests\config\test_config.py -> build\lib.win-amd64-cpython-313\pandas\tests\config
#   copying pandas\tests\config\test_localization.py -> build\lib.win-amd64-cpython-313\pandas\tests\config
#   copying pandas\tests\config\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\config
#   creating build\lib.win-amd64-cpython-313\pandas\tests\construction
#   copying pandas\tests\construction\test_extract_array.py -> build\lib.win-amd64-cpython-313\pandas\tests\construction
#   copying pandas\tests\construction\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\construction
#   creating build\lib.win-amd64-cpython-313\pandas\tests\copy_view
#   copying pandas\tests\copy_view\test_indexing.py -> build\lib.win-amd64-cpython-313\pandas\tests\copy_view
#   copying pandas\tests\copy_view\test_internals.py -> build\lib.win-amd64-cpython-313\pandas\tests\copy_view
#   copying pandas\tests\copy_view\test_methods.py -> build\lib.win-amd64-cpython-313\pandas\tests\copy_view
#   copying pandas\tests\copy_view\test_setitem.py -> build\lib.win-amd64-cpython-313\pandas\tests\copy_view
#   copying pandas\tests\copy_view\util.py -> build\lib.win-amd64-cpython-313\pandas\tests\copy_view
#   copying pandas\tests\copy_view\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\copy_view
#   creating build\lib.win-amd64-cpython-313\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_common.py -> build\lib.win-amd64-cpython-313\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_concat.py -> build\lib.win-amd64-cpython-313\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_dtypes.py -> build\lib.win-amd64-cpython-313\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_generic.py -> build\lib.win-amd64-cpython-313\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_inference.py -> build\lib.win-amd64-cpython-313\pandas\tests\dtypes
#   copying pandas\tests\dtypes\test_missing.py -> build\lib.win-amd64-cpython-313\pandas\tests\dtypes
#   copying pandas\tests\dtypes\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\dtypes
#   creating build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\conftest.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_arrow.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_boolean.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_categorical.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_common.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_datetime.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_extension.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_external_block.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_floating.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_integer.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_interval.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_numpy.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_period.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_sparse.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\test_string.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   copying pandas\tests\extension\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\extension
#   creating build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\common.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\conftest.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_alter_axes.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_api.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_arithmetic.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_block_internals.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_constructors.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_cumulative.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_iteration.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_logical_ops.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_nonunique_indexes.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_npfuncs.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_query_eval.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_reductions.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_repr_info.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_stack_unstack.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_subclass.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_ufunc.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_unary.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\test_validate.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   copying pandas\tests\frame\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\frame
#   creating build\lib.win-amd64-cpython-313\pandas\tests\generic
#   copying pandas\tests\generic\test_duplicate_labels.py -> build\lib.win-amd64-cpython-313\pandas\tests\generic
#   copying pandas\tests\generic\test_finalize.py -> build\lib.win-amd64-cpython-313\pandas\tests\generic
#   copying pandas\tests\generic\test_frame.py -> build\lib.win-amd64-cpython-313\pandas\tests\generic
#   copying pandas\tests\generic\test_generic.py -> build\lib.win-amd64-cpython-313\pandas\tests\generic
#   copying pandas\tests\generic\test_label_or_level_utils.py -> build\lib.win-amd64-cpython-313\pandas\tests\generic
#   copying pandas\tests\generic\test_series.py -> build\lib.win-amd64-cpython-313\pandas\tests\generic
#   copying pandas\tests\generic\test_to_xarray.py -> build\lib.win-amd64-cpython-313\pandas\tests\generic
#   copying pandas\tests\generic\__init__.py -> build\lib.win-amd64-cpython-313\pandas\tests\generic
#   creating build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\conftest.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_allowlist.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_any_all.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_apply.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_apply_mutate.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_bin_groupby.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_categorical.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_counting.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_filters.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_frame_value_counts.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_function.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_groupby.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_groupby_dropna.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_groupby_shift_diff.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_groupby_subclass.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_grouping.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_indexing.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_index_as_string.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_libgroupby.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_min_max.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_missing.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_nth.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_numba.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_nunique.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_pipe.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_quantile.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_rank.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_sample.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_size.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
#   copying pandas\tests\groupby\test_timegrouper.py -> build\lib.win-amd64-cpython-313\pandas\tests\groupby
# ...
#   copying pandas\_libs\reshape.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs
#   copying pandas\_libs\sparse.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs
#   copying pandas\_libs\sparse.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs
#   copying pandas\_libs\testing.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs
#   copying pandas\_libs\testing.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs
#   copying pandas\_libs\tslib.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs
#   copying pandas\_libs\tslib.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs
#   copying pandas\_libs\util.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs
#   copying pandas\_libs\writers.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs
#   copying pandas\_libs\writers.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs
#   creating build\lib.win-amd64-cpython-313\pandas\io\formats\templates
#   copying pandas\io\formats\templates\html.tpl -> build\lib.win-amd64-cpython-313\pandas\io\formats\templates
#   copying pandas\io\formats\templates\html_style.tpl -> build\lib.win-amd64-cpython-313\pandas\io\formats\templates
#   copying pandas\io\formats\templates\html_table.tpl -> build\lib.win-amd64-cpython-313\pandas\io\formats\templates
#   copying pandas\io\formats\templates\latex.tpl -> build\lib.win-amd64-cpython-313\pandas\io\formats\templates
#   copying pandas\io\formats\templates\latex_longtable.tpl -> build\lib.win-amd64-cpython-313\pandas\io\formats\templates
#   copying pandas\io\formats\templates\latex_table.tpl -> build\lib.win-amd64-cpython-313\pandas\io\formats\templates
#   copying pandas\io\formats\templates\string.tpl -> build\lib.win-amd64-cpython-313\pandas\io\formats\templates
#   copying pandas\io\sas\_sas.pyi -> build\lib.win-amd64-cpython-313\pandas\io\sas
#   copying pandas\io\sas\sas.pyx -> build\lib.win-amd64-cpython-313\pandas\io\sas
#   creating build\lib.win-amd64-cpython-313\pandas\tests\io\data
#   copying pandas\tests\io\data\gbq_fake_job.txt -> build\lib.win-amd64-cpython-313\pandas\tests\io\data
#   creating build\lib.win-amd64-cpython-313\pandas\tests\io\data\fixed_width
#   copying pandas\tests\io\data\fixed_width\fixed_width_format.txt -> build\lib.win-amd64-cpython-313\pandas\tests\io\data\fixed_width
#   creating build\lib.win-amd64-cpython-313\pandas\tests\io\data\legacy_pickle\1.2.4
#   copying pandas\tests\io\data\legacy_pickle\1.2.4\empty_frame_v1_2_4-GH#42345.pkl -> build\lib.win-amd64-cpython-313\pandas\tests\io\data\legacy_pickle\1.2.4
#   creating build\lib.win-amd64-cpython-313\pandas\tests\io\data\parquet
#   copying pandas\tests\io\data\parquet\simple.parquet -> build\lib.win-amd64-cpython-313\pandas\tests\io\data\parquet
#   creating build\lib.win-amd64-cpython-313\pandas\tests\io\data\pickle
#   copying pandas\tests\io\data\pickle\test_mi_py27.pkl -> build\lib.win-amd64-cpython-313\pandas\tests\io\data\pickle
#   copying pandas\tests\io\data\pickle\test_py27.pkl -> build\lib.win-amd64-cpython-313\pandas\tests\io\data\pickle
#   creating build\lib.win-amd64-cpython-313\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\baby_names.xml -> build\lib.win-amd64-cpython-313\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\books.xml -> build\lib.win-amd64-cpython-313\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\cta_rail_lines.kml -> build\lib.win-amd64-cpython-313\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\doc_ch_utf.xml -> build\lib.win-amd64-cpython-313\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\flatten_doc.xsl -> build\lib.win-amd64-cpython-313\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\row_field_output.xsl -> build\lib.win-amd64-cpython-313\pandas\tests\io\data\xml
#   copying pandas\_libs\tslibs\base.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\base.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\ccalendar.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\ccalendar.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\ccalendar.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\conversion.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\conversion.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\conversion.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\dtypes.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\dtypes.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\dtypes.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\fields.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\fields.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\nattype.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\nattype.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\nattype.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\np_datetime.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\np_datetime.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\np_datetime.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\offsets.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\offsets.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\offsets.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\parsing.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\parsing.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\parsing.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\period.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\period.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\period.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\strptime.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\strptime.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timedeltas.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timedeltas.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timedeltas.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timestamps.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timestamps.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timestamps.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timezones.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timezones.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timezones.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\tzconversion.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\tzconversion.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\tzconversion.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\util.pxd -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\vectorized.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\vectorized.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\tslibs
#   copying pandas\_libs\window\aggregations.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\window
#   copying pandas\_libs\window\aggregations.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\window
#   copying pandas\_libs\window\indexers.pyi -> build\lib.win-amd64-cpython-313\pandas\_libs\window
#   copying pandas\_libs\window\indexers.pyx -> build\lib.win-amd64-cpython-313\pandas\_libs\window
#   UPDATING build\lib.win-amd64-cpython-313\pandas/_version.py
#   set build\lib.win-amd64-cpython-313\pandas/_version.py to '1.5.3'
#   running build_ext
#   building 'pandas._libs.algos' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pandas
# ERROR: Could not build wheels for pandas, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: plotly==6.0.0 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (6.0.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from plotly==6.0.0) (1.27.1)
# Requirement already satisfied: packaging in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from plotly==6.0.0) (24.2)
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib==3.10.0 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib==3.10.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib==3.10.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib==3.10.0) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib==3.10.0) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib==3.10.0) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib==3.10.0) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib==3.10.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib==3.10.0) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib==3.10.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.10.0) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn==0.13.2 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from seaborn==0.13.2) (2.2.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from seaborn==0.13.2) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from seaborn==0.13.2) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: statsmodels in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (0.14.4)
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from statsmodels) (1.15.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\marti\pycharmprojects\week5_1_pandas\.env\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# # ESERCIZIO 1

# %%
df=pd.read_csv("df3.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10000 non-null  int64
#  1   a           10000 non-null  float64
#  2   b           10000 non-null  float64
#  3   c           10000 non-null  float64
#  4   d           10000 non-null  int64
#  5   x           10000 non-null  float64
#  6   y           10000 non-null  float64
#  7   z           10000 non-null  int64
#  8   h           10000 non-null  int64
#  9   g           10000 non-null  float64
#  10  f           10000 non-null  float64
# dtypes: float64(7), int64(4)
# memory usage: 859.5 KB

# %%
df.head()
# Out:
#    Unnamed: 0          a           b          c  d         x           y  z  \
# 0           0  19.087423  -45.948735  45.727892  0 -1.685862  -44.262872  0
# 1           1  20.487493  -35.777837  49.552648  1 -1.506121  -34.271716  0
# 2           2  18.690196   -8.861605  48.903702  0  0.052330   -8.913935  0
# 3           3  19.429664  124.437220  48.357539  1 -0.640684  125.077904  0
# 4           4  20.909506  113.067077  49.989816  0  0.140450  112.926626  0
#
#    h          g           f
# 0  0  47.413754   45.263782
# 1  0  51.058770  544.311461
# 2  0  48.851372    8.152672
# 3  0  48.998223  365.286478
# 4  0  49.849366 -112.405410

# %%
numeric_db = df.select_dtypes(include = ['int64', 'float64'])
#databadse in cui ho selezionato le colonne di un certo tipo

correlation = numeric_db.corr()['f'].sort_values(ascending = False)
#correlazione delle colonne del database con survived
#faccio il sort per ordinare le correlazioni con loro stessi (a 1) e le salto

plt.figure(figsize = (8,5))
top_features = correlation[1:]
sns.barplot(x = top_features.values, y = top_features.index)
plt.title('Top 9 Features Correlated with f')
plt.xlabel('Correlation Coefficient')
plt.tight_layout()
plt.show()

correlation.apply(lambda x: f"{x:.3f} ({'Strong' if abs(x) > 0.1 else 'Moderate' if abs(x) > 0.01 else 'Weak'})").head(10)
# Out:
# f               1.000 (Strong)
# d               0.929 (Strong)
# g             0.030 (Moderate)
# c             0.020 (Moderate)
# x                -0.002 (Weak)
# a                -0.006 (Weak)
# Unnamed: 0       -0.008 (Weak)
# h                -0.009 (Weak)
# y              -0.371 (Strong)
# b              -0.371 (Strong)
# Name: f, dtype: object

# %% [markdown]
# La correlazione più forte è quella tra f e d-y.
#
# y e b sembrano essere dipendenti tra loro.
#
# verifico con una mappa di correlazione traq tutte le variabili

# %%
# Correlation Heatmap for selected numeric columns
plt.figure(figsize=(16, 8))
cols = [ 'a',	'b',	'c',	'd',	'x',	'y',	'z',	'h',	'g',	'f']
corr = df[cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.1)
#sns.heatmap(corr, annot=False, cmap='coolwarm', linewidths=0.1)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Correlation Heatmap for selected numeric columns
plt.figure(figsize=(16, 8))
cols = [ 'a',	'b',	'c',	'd',	'x',	'y',	'h',	'g',	'f']
corr = df[cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.1)
#sns.heatmap(corr, annot=False, cmap='coolwarm', linewidths=0.1)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # ESERCIZIO 2
# Plot the function y = 1/x between -10 and 10

# %%
#x=np.linspace(-10,10,100)
#x=np.concatenate([np.linspace(-10,-2.5,5), np.linspace(-2.5,2.5,15),np.linspace(2.5,10,5)]) #in questo caso trova lo 0 in x
x=np.concatenate([np.linspace(-10,-2,5), np.linspace(-2,-0.1,10),np.linspace(0.1,2,10), np.linspace(2,10,5)]) #stesso intervallo della prima ma con meno punti
y= 1/x
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y=1/x")
plt.title("graph")
plt.show()

# %% [markdown]
# # Esercizio 3

# %%
# Generate simulation data for heatmap
x_vals = np.linspace(-5, 5, 50)
y_vals = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x_vals, y_vals)
Z = X**2 + Y**2

# Convert to DataFrame
df_simulation = pd.DataFrame({'x': X.ravel(), 'y': Y.ravel(), 'z': Z.ravel()})

# Pivot the data for heatmap
heatmap_data = df_simulation.pivot(index='y', columns='x', values='z')

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=False)
plt.title('Heatmap of z = x^2 + y^2')
plt.xlabel('x')
plt.ylabel('y')
plt.gca().invert_yaxis()
plt.show()

#trovo le curve di livello della heatmap
# Plot contour lines
plt.figure(figsize=(8, 6))
contour = plt.contour(X, Y, Z, cmap='coolwarm')
plt.clabel(contour, inline=True, fontsize=8)
plt.title('Contour Plot of z = x^2 + y^2')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()

# %%
# Generate simulation data for heatmap
x_vals = np.linspace(-5, 5, 50)
y_vals = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x_vals, y_vals)
Z = -X*Y

# Convert to DataFrame
df_simulation = pd.DataFrame({'x': X.ravel(), 'y': Y.ravel(), 'z': Z.ravel()})

# Pivot the data for heatmap
heatmap_data = df_simulation.pivot(index='y', columns='x', values='z')

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=False)
plt.title('Heatmap of z = _X*Y')
plt.xlabel('x')
plt.ylabel('y')
plt.gca().invert_yaxis()
plt.show()

#trovo le curve di livello della heatmap
# Plot contour lines
plt.figure(figsize=(8, 6))
contour = plt.contour(X, Y, Z, cmap='coolwarm')
plt.clabel(contour, inline=True, fontsize=8)
plt.title('Contour Plot of z = -X*Y')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()

# %%
# Generate simulation data for heatmap
x_vals = np.linspace(-5, 5, 50)
y_vals = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x_vals, y_vals)
R=np.max(X)-1
r=np.max(X)-2
h=np.max(Y)-np.min(Y)
Z = np.pi*(R+r)*((R-r)**2 + h**2)**(-1/2)
#Z=np.log(X**2+Y**2+1)
# Convert to DataFrame
df_simulation = pd.DataFrame({'x': X.ravel(), 'y': Y.ravel(), 'z': Z.ravel()})

# Pivot the data for heatmap
heatmap_data = df_simulation.pivot(index='y', columns='x', values='z')

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=False)
plt.title('Heatmap of z = ')
plt.xlabel('x')
plt.ylabel('y')
plt.gca().invert_yaxis()
plt.show()

#trovo le curve di livello della heatmap
# Plot contour lines
plt.figure(figsize=(8, 6))
contour = plt.contour(X, Y, Z, cmap='coolwarm')
plt.clabel(contour, inline=True, fontsize=8)
plt.title('Contour Plot of z = ')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 11
#       8 Z = np.pi*(R+r)*((R-r)**2 + h**2)**(-1/2)
#       9 #Z=np.log(X**2+Y**2+1)
#      10 # Convert to DataFrame
# ---> 11 df_simulation = pd.DataFrame({'x': X.ravel(), 'y': Y.ravel(), 'z': Z.ravel()})
#      13 # Pivot the data for heatmap
#      14 heatmap_data = df_simulation.pivot(index='y', columns='x', values='z')
#
# File ~\PycharmProjects\week5_1_pandas\.env\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~\PycharmProjects\week5_1_pandas\.env\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\PycharmProjects\week5_1_pandas\.env\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~\PycharmProjects\week5_1_pandas\.env\Lib\site-packages\pandas\core\internals\construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length
